# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
import pandas as pd

# %%
data = pd.read_csv("COVID Data Collection - Data for Peak Prediction.csv")

# %%
data.replace("Y",1,inplace=True)

# %%
data.replace("N",0,inplace=True)

# %%
data.head()
# Out:
#           Country Young Population\n(Aged under 15 )  \
# 0         Germany                             13.50%
# 1          Russia                             17.91%
# 2  United Kingdom                             18.90%
# 3          France                             18.1 %
# 4           Italy                             13.5 %
#
#   Working Age Population\n(Aged between 15 - 64)  \
# 0                                            65%
# 1                                         67.41%
# 2                                         63.10%
# 3                                         62.2 %
# 4                                         63.5 %
#
#   Elderly population\n(Aged 65 and over)  Population   \
# 0                                 21.47%   83,783,942
# 1                                 14.67%  145,934,462
# 2                                 18.00%     67886011
# 3                                 19.7 %     65273511
# 4                                 23.0 %   60,461,826
#
#   Population Density \n(per Km2) Political Ideology  Death Rate  \
# 0                            240          Democratic      4.70%
# 1                              9       Authoritarian      1.25%
# 2                            281          Democratic     14.20%
# 3                            119          Democratic     18.97%
# 4                            206          Democratic     14.41%
#
#    Social Distancing\n(days)  Wearing Face mask\n(days)  \
# 0                         99                         44
# 1                         45                         64
# 2                         99                         15
# 3                         55                         51
# 4                         70                         63
#
#    14 day Quarantine\n(days)  Boarders\n(days)  School closures\n(days)  \
# 0                         70                91                       52
# 1                          0               104                        0
# 2                         60               105                       87
# 3                         50                70                       55
# 4                         86                67                      118
#
#    Lockdown
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1

# %%
country=["Germany"
         ,"Russia"
         ,"United Kingdom","France","Italy","Spain","Ukraine","Poland","Romania","Netherlands","Belgium","Czech Republic","Greece","Portugal"
,"Sweden"
,"Hungary"
,"Belarus"
,"Austria"
,"Serbia"
,"Switzerland"
,"Bulgaria"
,"Denmark"
,"Finland"
,"Slovakia"
,"Norway"
,"Ireland"
,"Croatia"
,"Moldova"
,"Bosnia and Herzegovina"
,"Albania"
,"Lithuania"
,"North Macedonia"
,"Slovenia"
,"Latvia"
,"Estonia"
,"Montenegro"
,"Luxembourg"
,"Malta"
,"Iceland"
,"Canada"
,"Australia"
,"New Zealand"]

# %%
country
# Out:
# ['Germany',
#  'Russia',
#  'United Kingdom',
#  'France',
#  'Italy',
#  'Spain',
#  'Ukraine',
#  'Poland',
#  'Romania',
#  'Netherlands',
#  'Belgium',
#  'Czech Republic',
#  'Greece',
#  'Portugal',
#  'Sweden',
#  'Hungary',
#  'Belarus',
#  'Austria',
#  'Serbia',
#  'Switzerland',
#  'Bulgaria',
#  'Denmark',
#  'Finland',
#  'Slovakia',
#  'Norway',
#  'Ireland',
#  'Croatia',
#  'Moldova',
#  'Bosnia and Herzegovina',
#  'Albania',
#  'Lithuania',
#  'North Macedonia',
#  'Slovenia',
#  'Latvia',
#  'Estonia',
#  'Montenegro',
#  'Luxembourg',
#  'Malta',
#  'Iceland',
#  'Canada',
#  'Australia',
#  'New Zealand']

# %%
covid = pd.read_csv("owid-covid-data.csv")

# %%
covid["date"] = pd.to_datetime(covid["date"],format="%Y-%m-%d")

# %%
covid.set_index("location",inplace=True)

# %%
covid.columns
# Out:
# Index(['iso_code', 'continent', 'date', 'total_cases', 'new_cases',
#        'total_deaths', 'new_deaths', 'total_cases_per_million',
#        'new_cases_per_million', 'total_deaths_per_million',
#        'new_deaths_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'tests_units',
#        'stringency_index', 'population', 'population_density', 'median_age',
#        'aged_65_older', 'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cvd_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand'],
#       dtype='object')

# %%
germany = covid.loc[(covid["total_cases"]>30)&(covid.index=="Germany"),["date","total_cases"]]

# %%
max = germany["total_cases"].max()

# %%
min = germany["total_cases"].min()

# %%
germany
# Out:
#                date  total_cases
# location
# Germany  2020-02-28           47
# Germany  2020-02-29           57
# Germany  2020-03-01          111
# Germany  2020-03-02          129
# Germany  2020-03-03          157
# Germany  2020-03-04          196
# Germany  2020-03-05          262
# Germany  2020-03-06          400
# Germany  2020-03-07          684
# Germany  2020-03-08          847
# Germany  2020-03-09          902
# Germany  2020-03-10         1139
# Germany  2020-03-11         1296
# Germany  2020-03-12         1567
# Germany  2020-03-13         2369
# Germany  2020-03-14         3062
# Germany  2020-03-15         3795
# Germany  2020-03-16         4838
# Germany  2020-03-17         6012
# Germany  2020-03-18         7156
# Germany  2020-03-19         8198
# Germany  2020-03-20        14138
# Germany  2020-03-21        18187
# Germany  2020-03-22        21463
# Germany  2020-03-23        24774
# Germany  2020-03-24        29212
# Germany  2020-03-25        31554
# Germany  2020-03-26        36508
# Germany  2020-03-27        42288
# Germany  2020-03-28        48582
# ...             ...          ...
# Germany  2020-05-09       168551
# Germany  2020-05-10       169218
# Germany  2020-05-11       169575
# Germany  2020-05-12       170508
# Germany  2020-05-13       171306
# Germany  2020-05-14       172239
# Germany  2020-05-15       173152
# Germany  2020-05-16       173772
# Germany  2020-05-17       174355
# Germany  2020-05-18       174697
# Germany  2020-05-19       175210
# Germany  2020-05-20       176007
# Germany  2020-05-21       176752
# Germany  2020-05-22       177212
# Germany  2020-05-23       177850
# Germany  2020-05-24       178281
# Germany  2020-05-25       178570
# Germany  2020-05-26       179002
# Germany  2020-05-27       179364
# Germany  2020-05-28       179717
# Germany  2020-05-29       180458
# Germany  2020-05-30       181196
# Germany  2020-05-31       181482
# Germany  2020-06-01       181815
# Germany  2020-06-02       182028
# Germany  2020-06-03       182370
# Germany  2020-06-04       182764
# Germany  2020-06-05       183271
# Germany  2020-06-06       183678
# Germany  2020-06-07       183979
#
# [101 rows x 2 columns]

# %%
max_date = germany.loc[germany["total_cases"]==max,"date"]

# %%
min_date = germany.loc[germany["total_cases"]==min,"date"]

# %%
max_date
# Out:
# location
# Germany   2020-06-07
# Name: date, dtype: datetime64[ns]

# %%
import datetime

# %%
germany_days = max_date - min_date

# %%
germany_day = germany_days.dt.days

# %%
day_list=[]

# %%
day_list.append(germany_day)

# %%
day_list
# Out:
# [location
#  Germany    100
#  Name: date, dtype: int64]

# %%
day_list = []

# %%
for i in country:
    each_country = covid.loc[(covid["total_cases"]>30)&(covid.index==i),["date","total_cases"]]
    max_count = each_country["total_cases"].max()
    min_count = each_country["total_cases"].min()
    max_date = each_country.loc[each_country["total_cases"]==max_count,"date"]
    min_date = each_country.loc[each_country["total_cases"]==min_count ,"date"]
    days_to_peak = max_date - min_date
    get_days = days_to_peak.dt.days
    day_list.append(get_days)

# %%
day_list
# Out:
# [location
#  Germany    100
#  Name: date, dtype: int64, location
#  Russia    85
#  Name: date, dtype: int64, location
#  United Kingdom    97
#  Name: date, dtype: int64, location
#  France    100
#  Name: date, dtype: int64, location
#  Italy    105
#  Name: date, dtype: int64, location
#  Spain    99
#  Name: date, dtype: int64, location
#  Ukraine    76
#  Ukraine    77
#  Name: date, dtype: int64, location
#  Poland    87
#  Name: date, dtype: int64, location
#  Romania    87
#  Name: date, dtype: int64, location
#  Netherlands    94
#  Name: date, dtype: int64, location
#  Belgium    93
#  Name: date, dtype: int64, location
#  Czech Republic    90
#  Name: date, dtype: int64, location
#  Greece    93
#  Name: date, dtype: int64, location
#  Portugal    89
#  Name: date, dtype: int64, location
#  Sweden    94
#  Name: date, dtype: int64, location
#  Hungary    83
#  Hungary    84
#  Name: date, dtype: int64, location
#  Belarus    82
#  Belarus    81
#  Name: date, dtype: int64, location
#  Austria    93
#  Name: date, dtype: int64, location
#  Serbia    85
#  Name: date, dtype: int64, location
#  Switzerland    95
#  Name: date, dtype: int64, location
#  Bulgaria    85
#  Name: date, dtype: int64, location
#  Denmark    91
#  Name: date, dtype: int64, location
#  Finland    89
#  Name: date, dtype: int64, location
#  Slovakia    84
#  Name: date, dtype: int64, location
#  Norway    94
#  Norway    95
#  Name: date, dtype: int64, location
#  Ireland    88
#  Name: date, dtype: int64, location
#  Croatia    83
#  Croatia    84
#  Croatia    85
#  Name: date, dtype: int64, location
#  Moldova    80
#  Name: date, dtype: int64, location
#  Bosnia and Herzegovina    79
#  Bosnia and Herzegovina    80
#  Name: date, dtype: int64, location
#  Albania    85
#  Name: date, dtype: int64, location
#  Lithuania    80
#  Name: date, dtype: int64, Series([], Name: date, dtype: int64), location
#  Slovenia    88
#  Name: date, dtype: int64, location
#  Latvia    83
#  Name: date, dtype: int64, location
#  Estonia    85
#  Name: date, dtype: int64, location
#  Montenegro    42
#  Montenegro    43
#  Montenegro    44
#  Montenegro    45
#  Montenegro    46
#  Montenegro    47
#  Montenegro    48
#  Montenegro    49
#  Montenegro    50
#  Montenegro    51
#  Montenegro    52
#  Montenegro    53
#  Montenegro    54
#  Montenegro    55
#  Montenegro    56
#  Montenegro    57
#  Montenegro    58
#  Montenegro    59
#  Montenegro    60
#  Montenegro    61
#  Montenegro    62
#  Montenegro    63
#  Montenegro    64
#  Montenegro    65
#  Montenegro    66
#  Montenegro    67
#  Montenegro    68
#  Montenegro    69
#  Montenegro    70
#  Montenegro    71
#  Montenegro    72
#  Montenegro    73
#  Montenegro    74
#  Name: date, dtype: int64, location
#  Luxembourg    85
#  Name: date, dtype: int64, location
#  Malta    79
#  Malta    80
#  Malta    81
#  Malta    82
#  Name: date, dtype: int64, location
#  Iceland    86
#  Iceland    87
#  Iceland    88
#  Iceland    89
#  Iceland    90
#  Iceland    91
#  Iceland    92
#  Iceland    93
#  Name: date, dtype: int64, location
#  Canada    94
#  Name: date, dtype: int64, location
#  Australia    96
#  Name: date, dtype: int64, location
#  New Zealand    63
#  New Zealand    64
#  New Zealand    65
#  New Zealand    66
#  New Zealand    67
#  New Zealand    68
#  New Zealand    69
#  New Zealand    70
#  New Zealand    71
#  New Zealand    72
#  New Zealand    73
#  New Zealand    74
#  New Zealand    75
#  New Zealand    76
#  New Zealand    77
#  New Zealand    78
#  New Zealand    79
#  Name: date, dtype: int64]

# %%
covid_data = pd.read_csv("COVID Data Collection- Data for Peak Prediction.csv")

# %%
covid_data.set_index("Country",inplace= True)

# %%
covid_data.head()
# Out:
#                Young Population\n(Aged under 15 )  \
# Country
# USA                                        18.62%
# Germany                                    13.50%
# Russia                                     17.91%
# United Kingdom                             18.90%
# France                                     18.1 %
#
#                Working Age Population\n(Aged between 15 - 64)  \
# Country
# USA                                                    65.35%
# Germany                                                65.00%
# Russia                                                 67.41%
# United Kingdom                                         63.10%
# France                                                 62.2 %
#
#                Elderly population\n(Aged 65 and over)  Population   \
# Country
# USA                                            16.03%     32823952
# Germany                                        21.47%     83783942
# Russia                                         14.67%    145934462
# United Kingdom                                 18.00%     67886011
# France                                         19.7 %     65273511
#
#                 Population Density \n(per Km2) Political Ideology  Death Rate  \
# Country
# USA                                         34          Democratic      5.60%
# Germany                                    240          Democratic      4.70%
# Russia                                       9       Authoritarian      1.25%
# United Kingdom                             281          Democratic     14.20%
# France                                     119          Democratic     18.97%
#
#                 Social Distancing\n(days)  Wearing Face mask\n(days)  \
# Country
# USA                                   103                          0
# Germany                                49                         44
# Russia                                 45                         64
# United Kingdom                         99                         15
# France                                 55                         51
#
#                 14 day Quarantine\n(days)  Boarders\n(days)  \
# Country
# USA                                   149               109
# Germany                                70                91
# Russia                                  0               104
# United Kingdom                         60               105
# France                                 50                70
#
#                 School closures\n(days) Lockdown  Days to Peak
# Country
# USA                                 106        Y           NaN
# Germany                              52        Y         100.0
# Russia                                0        Y          85.0
# United Kingdom                       87        Y          97.0
# France                               55        Y         100.0

# %%
covid_data.replace("Y",1,inplace = True)
covid_data.replace("N",0,inplace=True)

# %%
covid_data.replace("Democratic",1,inplace = True)
covid_data.replace("Authoritarian",0,inplace = True)

# %%
covid_data.dtypes
# Out:
# Young Population\n(Aged under 15 )                 object
# Working Age Population\n(Aged between 15 - 64)     object
# Elderly population\n(Aged 65 and over)             object
# Population                                          int64
# Population Density \n(per Km2)                      int64
# Political Ideology                                  int64
# Death Rate                                         object
# Social Distancing\n(days)                           int64
# Wearing Face mask\n(days)                           int64
# 14 day Quarantine\n(days)                           int64
# Boarders\n(days)                                    int64
# School closures\n(days)                             int64
# Lockdown                                            int64
# Days to Peak                                      float64
# dtype: object

# %%
covid_data
# Out:
#                         Young Population\n(Aged under 15 )  \
# Country
# USA                                                 0.1862
# Germany                                             0.1350
# Russia                                              0.1791
# United Kingdom                                      0.1890
# France                                              0.1810
# Italy                                               0.1350
# Spain                                               0.1470
# Ukraine                                             0.1550
# Poland                                              0.1480
# Romania                                             0.1530
# Netherlands                                         0.1790
# Belgium                                             0.1710
# Czech Republic                                      0.1540
# Greece                                              0.1420
# Portugal                                            0.1360
# Sweden                                              0.1750
# Hungary                                             0.1430
# Belarus                                             0.1670
# Austria                                             0.1410
# Serbia                                              0.1650
# Switzerland                                         0.1490
# Bulgaria                                            0.1420
# Denmark                                             0.1650
# Finland                                             0.1640
# Slovakia                                            0.1540
# Norway                                              0.1780
# Ireland                                             0.2160
# Croatia                                             0.1470
# Moldova                                             0.1570
# Bosnia and Herzegovina                              0.1410
# Albania                                             0.1740
# Lithuania                                           0.1480
# North Macedonia                                     0.2500
# Slovenia                                            0.1500
# Latvia                                              0.1540
# Estonia                                             0.1640
# Montenegro                                          0.1810
# Luxembourg                                          0.1650
# Malta                                               0.1440
# Iceland                                             0.2010
# Canada                                              0.1600
# Australia                                           0.1900
# New Zealand                                         0.1980
#
#                         Working Age Population\n(Aged between 15 - 64)  \
# Country
# USA                                                             0.6535
# Germany                                                         0.6500
# Russia                                                          0.6741
# United Kingdom                                                  0.6310
# France                                                          0.6220
# Italy                                                           0.6350
# Spain                                                           0.6590
# Ukraine                                                         0.6800
# Poland                                                          0.6840
# Romania                                                         0.6690
# Netherlands                                                     0.6900
# Belgium                                                         0.6430
# Czech Republic                                                  0.6560
# Greece                                                          0.6540
# Portugal                                                        0.6490
# Sweden                                                          0.6250
# Hungary                                                         0.6710
# Belarus                                                         0.6850
# Austria                                                         0.6670
# Serbia                                                          0.6620
# Switzerland                                                     0.6670
# Bulgaria                                                        0.6500
# Denmark                                                         0.6380
# Finland                                                         0.6240
# Slovakia                                                        0.6960
# Norway                                                          0.6540
# Ireland                                                         0.6440
# Croatia                                                         0.6560
# Moldova                                                         0.7340
# Bosnia and Herzegovina                                          0.6930
# Albania                                                         0.6890
# Lithuania                                                       0.6620
# North Macedonia                                                 0.6620
# Slovenia                                                        0.6600
# Latvia                                                          0.6480
# Estonia                                                         0.6420
# Montenegro                                                      0.6710
# Luxembourg                                                      0.6920
# Malta                                                           0.6610
# Iceland                                                         0.6550
# Canada                                                          0.6700
# Australia                                                       0.6550
# New Zealand                                                     0.6490
#
#                         Elderly population\n(Aged 65 and over)  Population   \
# Country
# USA                                                     0.1603     32823952
# Germany                                                 0.2147     83783942
# Russia                                                  0.1467    145934462
# United Kingdom                                          0.1800     67886011
# France                                                  0.1970     65273511
# Italy                                                   0.2300     60461826
# Spain                                                   0.1940     46754778
# Ukraine                                                 0.1650     43733762
# Poland                                                  0.1680     37846611
# Romania                                                 0.1790     19237691
# Netherlands                                             0.1310     17134872
# Belgium                                                 0.1860     11589623
# Czech Republic                                          0.1900     10708981
# Greece                                                  0.2040     10423054
# Portugal                                                0.2150     10196709
# Sweden                                                  0.1990     10099265
# Hungary                                                 0.1860      9660351
# Belarus                                                 0.1480      9449323
# Austria                                                 0.1920      9006398
# Serbia                                                  0.1740      8737371
# Switzerland                                             0.1840      8654622
# Bulgaria                                                0.2080      6948445
# Denmark                                                 0.1970      5792202
# Finland                                                 0.2120      5540720
# Slovakia                                                0.1510      5459642
# Norway                                                  0.1680      5421241
# Ireland                                                 0.1390      4937786
# Croatia                                                 0.1970      4105267
# Moldova                                                 0.1090      4033963
# Bosnia and Herzegovina                                  0.1660      3280819
# Albania                                                 0.1320      2877797
# Lithuania                                               0.1900      2722289
# North Macedonia                                         0.0890      2083374
# Slovenia                                                0.1910      2078938
# Latvia                                                  0.1980      1886198
# Estonia                                                 0.1950      1326535
# Montenegro                                              0.1480       628066
# Luxembourg                                              0.1430       625978
# Malta                                                   0.1940       441543
# Iceland                                                 0.1440       341243
# Canada                                                  0.1700     37742154
# Australia                                               0.1550     25499884
# New Zealand                                             0.1530      4822233
#
#                         Population Density \n(per Km2)  Political Ideology   \
# Country
# USA                                                 34                    1
# Germany                                            240                    1
# Russia                                               9                    0
# United Kingdom                                     281                    1
# France                                             119                    1
# Italy                                              206                    1
# Spain                                               94                    1
# Ukraine                                             75                    1
# Poland                                             124                    1
# Romania                                             84                    1
# Netherlands                                        508                    1
# Belgium                                            383                    1
# Czech Republic                                     139                    1
# Greece                                              81                    1
# Portugal                                           111                    1
# Sweden                                              25                    1
# Hungary                                            107                    1
# Belarus                                             47                    0
# Austria                                            109                    1
# Serbia                                             100                    1
# Switzerland                                        219                    1
# Bulgaria                                            64                    1
# Denmark                                            137                    1
# Finland                                             18                    1
# Slovakia                                           114                    1
# Norway                                              15                    1
# Ireland                                             72                    1
# Croatia                                             73                    1
# Moldova                                            123                    1
# Bosnia and Herzegovina                              64                    1
# Albania                                            105                    1
# Lithuania                                           43                    1
# North Macedonia                                     83                    1
# Slovenia                                           103                    1
# Latvia                                              30                    1
# Estonia                                             31                    1
# Montenegro                                          47                    1
# Luxembourg                                         242                    1
# Malta                                             1380                    1
# Iceland                                              3                    1
# Canada                                               4                    1
# Australia                                            3                    1
# New Zealand                                         18                    1
#
#                         Death Rate  Social Distancing\n(days)  \
# Country
# USA                         0.0560                        103
# Germany                     0.0470                         49
# Russia                      0.0125                         45
# United Kingdom              0.1420                         99
# France                      0.1897                         55
# Italy                       0.1441                         70
# Spain                       0.0940                         56
# Ukraine                     0.0292                         38
# Poland                      0.0440                         29
# Romania                     0.0654                         48
# Netherlands                 0.1270                         60
# Belgium                     0.1620                         47
# Czech Republic              0.0341                         27
# Greece                      0.0604                         42
# Portugal                    0.0429                         20
# Sweden                      0.1061                          0
# Hungary                     0.1362                         13
# Belarus                     0.0055                          0
# Austria                     0.0398                         28
# Serbia                      0.0211                         50
# Switzerland                 0.0620                         42
# Bulgaria                    0.0590                         62
# Denmark                     0.0492                        109
# Finland                     0.0463                         20
# Slovakia                    0.0183                         37
# Norway                      0.0279                         60
# Ireland                     0.0666                         67
# Croatia                     0.0463                         32
# Moldova                     0.0352                        105
# Bosnia and Herzegovina      0.0610                         74
# Albania                     0.0272                        109
# Lithuania                   0.0414                         42
# North Macedonia             0.0518                        123
# Slovenia                    0.0735                     -43906
# Latvia                      0.0230                         88
# Estonia                     0.0356                     -43903
# Montenegro                  0.0278                         98
# Luxembourg                  0.0273                        107
# Malta                       0.0144                        100
# Iceland                     0.0055                         98
# Canada                      0.0818                        106
# Australia                   0.0141                         99
# New Zealand                 0.0146                         49
#
#                         Wearing Face mask\n(days)  14 day Quarantine\n(days)  \
# Country
# USA                                             0                        149
# Germany                                        44                         70
# Russia                                         64                          0
# United Kingdom                                 15                         60
# France                                         51                         50
# Italy                                          63                         86
# Spain                                          41                         99
# Ukraine                                         0                        111
# Poland                                         75                        107
# Romania                                        46                        123
# Netherlands                                    29                         49
# Belgium                                        41                        110
# Czech Republic                                 67                        116
# Greece                                         62                        106
# Portugal                                       58                          0
# Sweden                                          0                          0
# Hungary                                        64                         95
# Belarus                                         0                         97
# Austria                                        85                          0
# Serbia                                          0                        107
# Switzerland                                     0                        109
# Bulgaria                                        0                        109
# Denmark                                         0                        109
# Finland                                        76                        106
# Slovakia                                       97                        109
# Norway                                          0                          0
# Ireland                                         0                          0
# Croatia                                         0                        109
# Moldova                                         0                          0
# Bosnia and Herzegovina                         93                        107
# Albania                                         0                        107
# Lithuania                                      19                        106
# North Macedonia                                69                        106
# Slovenia                                       93                          0
# Latvia                                         49                        108
# Estonia                                        68                        109
# Montenegro                                    109                        109
# Luxembourg                                     71                          0
# Malta                                           0                        111
# Iceland                                         0                        104
# Canada                                         41                        106
# Australia                                       0                         97
# New Zealand                                     0                        106
#
#                         Boarders\n(days)  School closures\n(days)  Lockdown  \
# Country
# USA                                  109                      106         1
# Germany                               91                       52         1
# Russia                               104                        0         1
# United Kingdom                       105                       87         1
# France                                70                       55         1
# Italy                                 67                      118         1
# Spain                                105                      113         1
# Ukraine                               78                      111         1
# Poland                                90                      106         1
# Romania                              100                      112         1
# Netherlands                           92                       79         1
# Belgium                               87                      110         1
# Czech Republic                        93                       61         1
# Greece                                93                       66         1
# Portugal                             107                       67         1
# Sweden                                 0                        0         1
# Hungary                               90                       78         1
# Belarus                                0                       87         0
# Austria                               91                      104         1
# Serbia                                 0                      107         1
# Switzerland                           90                       29         1
# Bulgaria                             106                      111         1
# Denmark                               93                      106         1
# Finland                              103                       59         1
# Slovakia                              68                       81         1
# Norway                                 0                      -70         0
# Ireland                                0                      110         1
# Croatia                              103                      110         1
# Moldova                              105                      111         1
# Bosnia and Herzegovina                92                      112         1
# Albania                              107                      113         1
# Lithuania                             45                       74         1
# North Macedonia                      105                      112         1
# Slovenia                              66                      110         1
# Latvia                               105                      109         1
# Estonia                              105                      109         1
# Montenegro                            80                      109         1
# Luxembourg                             0                      106         1
# Malta                                  0                      110         1
# Iceland                               89                      106         1
# Canada                               106                       99         1
# Australia                            102                       68         1
# New Zealand                          103                       24         1
#
#                         Days to Peak
# Country
# USA                              NaN
# Germany                        100.0
# Russia                          85.0
# United Kingdom                  97.0
# France                         100.0
# Italy                          105.0
# Spain                           99.0
# Ukraine                         76.0
# Poland                          87.0
# Romania                         87.0
# Netherlands                     94.0
# Belgium                         93.0
# Czech Republic                  90.0
# Greece                          93.0
# Portugal                        89.0
# Sweden                          94.0
# Hungary                         83.0
# Belarus                         82.0
# Austria                         93.0
# Serbia                          85.0
# Switzerland                     95.0
# Bulgaria                        85.0
# Denmark                         91.0
# Finland                         89.0
# Slovakia                        84.0
# Norway                          94.0
# Ireland                         88.0
# Croatia                         83.0
# Moldova                         80.0
# Bosnia and Herzegovina          79.0
# Albania                         85.0
# Lithuania                       80.0
# North Macedonia                 88.0
# Slovenia                        83.0
# Latvia                          85.0
# Estonia                         85.0
# Montenegro                      42.0
# Luxembourg                      85.0
# Malta                           79.0
# Iceland                         86.0
# Canada                          94.0
# Australia                       96.0
# New Zealand                     63.0

# %%
# df['col'] = df['col'].str.rstrip('%').astype('float') / 100.0
covid_data["Young Population\n(Aged under 15 )"] = covid_data["Young Population\n(Aged under 15 )"].str.rstrip('%').astype('float') / 100.0
covid_data["Working Age Population\n(Aged between 15 - 64)"] = covid_data["Working Age Population\n(Aged between 15 - 64)"].str.rstrip('%').astype('float') / 100.0
covid_data["Elderly population\n(Aged 65 and over)"] = covid_data["Elderly population\n(Aged 65 and over)"].str.rstrip("%").astype('float') / 100.0

# %%
covid_data["Death Rate"] = covid_data["Death Rate"].str.rstrip('%').astype('float') / 100.0

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X = covid_data.loc["Germany":,:"Lockdown"]

# %%
covid_data["Days to Peak"]
# Out:
# Country
# USA                         NaN
# Germany                   100.0
# Russia                     85.0
# United Kingdom             97.0
# France                    100.0
# Italy                     105.0
# Spain                      99.0
# Ukraine                    76.0
# Poland                     87.0
# Romania                    87.0
# Netherlands                94.0
# Belgium                    93.0
# Czech Republic             90.0
# Greece                     93.0
# Portugal                   89.0
# Sweden                     94.0
# Hungary                    83.0
# Belarus                    82.0
# Austria                    93.0
# Serbia                     85.0
# Switzerland                95.0
# Bulgaria                   85.0
# Denmark                    91.0
# Finland                    89.0
# Slovakia                   84.0
# Norway                     94.0
# Ireland                    88.0
# Croatia                    83.0
# Moldova                    80.0
# Bosnia and Herzegovina     79.0
# Albania                    85.0
# Lithuania                  80.0
# North Macedonia            88.0
# Slovenia                   83.0
# Latvia                     85.0
# Estonia                    85.0
# Montenegro                 42.0
# Luxembourg                 85.0
# Malta                      79.0
# Iceland                    86.0
# Canada                     94.0
# Australia                  96.0
# New Zealand                63.0
# Name: Days to Peak, dtype: float64

# %%
Y = covid_data["Days to Peak"].dropna()

# %%
x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size = 0.2, random_state=0)

# %%
x_train.shape
# Out:
# (33, 13)

# %%
len(x_test)
# Out:
# 9

# %%
regr = LinearRegression()

# %%
regr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_predict = regr.predict(x_test)

# %%
plt.scatter(y_test, y_predict)
plt.plot([0,100],[0,100],"r")
plt.xlabel("Actual days")
plt.ylabel("Predicted days")
# Out:
# Text(0, 0.5, 'Predicted days')

# %%
y_predict - y_test
# Out:
# Country
# Lithuania                  2.902480
# Luxembourg                -4.521716
# Moldova                    7.675718
# Italy                     -5.974527
# Belgium                    2.319865
# Ireland                   -1.670642
# Bosnia and Herzegovina    -0.467072
# Czech Republic            -7.776746
# Malta                     21.614473
# Name: Days to Peak, dtype: float64

# %%
usa = covid_data.loc["USA",:"Lockdown"]

# %%
usa = usa.values.reshape(1,13)

# %%
usa_predict = regr.predict(usa)

# %% [markdown]
# ### USA will reach its peak on 5/21

# %%
usa_predict
# Out:
# array([87.55054348])

# %%
each_country = covid.loc[(covid["total_cases"]>30)&(covid.index=="United States"),["date","total_cases"]]
max_count = each_country["total_cases"].max()
min_count = each_country["total_cases"].min()
max_date = each_country.loc[each_country["total_cases"]==max_count,"date"]
min_date = each_country.loc[each_country["total_cases"]==min_count ,"date"]
days_to_peak = max_date - min_date
get_days = days_to_peak.dt.days
day_list.append(get_days)

# %%
max_date
min_date
# Out:
# location
# United States   2020-02-22
# United States   2020-02-23
# United States   2020-02-24
# Name: date, dtype: datetime64[ns]

# %% [markdown]
# ### Plotting each features' correlation to "days to peak"

# %%
days_to_peak = covid_data.iloc[1:,-1].to_numpy()
plt.figure(figsize=(10,12))
for i, feature in enumerate(covid_data.columns):
    plt.subplot(5,3,i+1)
    features = covid_data.iloc[1:,i].to_numpy()
    plt.scatter(features, days_to_peak, s=2)
    plt.ylabel("Days")
    plt.xlabel(feature)
    plt.tight_layout()
